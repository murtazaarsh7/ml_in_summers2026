# %% [markdown]
# <a href="https://colab.research.google.com/github/murtazaarsh7/ml_in_summers2026/blob/main/Word2vec_proj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/stranger_things_all_dialogue.csv')

# %%
df['raw_text'][10]
# Out:
# '-It is almost here. -What is it?'

# %%
df['dialogue'][10]
# Out:
# 'It is almost here. What is it?'

# %%
df = df.dropna(subset=['dialogue'])

# %%
df
# Out:
#        season  episode  line  \
# 8           1        1     9
# 9           1        1    10
# 10          1        1    11
# 11          1        1    12
# 12          1        1    13
# ...       ...      ...   ...
# 32512       4        9  2216
# 32513       4        9  2217
# 32514       4        9  2218
# 32515       4        9  2219
# 32517       4        9  2221
#
#                                                 raw_text stage_direction  \
# 8      [Mike] Something is coming. Something hungry f...          [Mike]
# 9      A shadow grows on the wall behind you, swallow...             NaN
# 10                      -It is almost here. -What is it?             NaN
# 11                          What if it's the Demogorgon?             NaN
# 12     Oh, Jesus, we're so screwed if it's the Demogo...             NaN
# ...                                                  ...             ...
# 32512                               ♪ We are entranced ♪             NaN
# ...

# %%
# !pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.8/27.8 MB 62.6 MB/s eta 0:00:00
# ...

# %%
import gensim
import os
import nltk

# %%
from nltk import sent_tokenize,word_tokenize
from gensim.utils import simple_preprocess

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
story=[]
for raw in df['dialogue']:
  raw_sent=sent_tokenize(raw)
  for sent in raw_sent:
    story.append(simple_preprocess(sent))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
story
# Out:
# [['something', 'is', 'coming'],
#  ['something', 'hungry', 'for', 'blood'],
#  ['shadow',
#   'grows',
#   'on',
#   'the',
#   'wall',
#   'behind',
#   'you',
#   'swallowing',
#   'you',
#   'in',
#   'darkness'],
#  ['it', 'is', 'almost', 'here'],
#  ['what', 'is', 'it'],
#  ['what', 'if', 'it', 'the', 'demogorgon'],
#  ['oh', 'jesus', 'we', 're', 'so', 'screwed', 'if', 'it', 'the', 'demogorgon'],
#  ['it', 'not', 'the', 'demogorgon'],
#  ['an', 'army', 'of', 'troglodytes', 'charge', 'into', 'the', 'chamber'],
#  ['troglodytes'],
#  ['told', 'ya'],
#  ['wait', 'minute'],
#  ['did', 'you', 'hear', 'that'],
#  ['that', 'that', 'sound'],
#  ['boom', 'boom'],
#  ['boom'],
#  ['that', 'didn', 'come', 'from', 'the', 'troglodytes'],
#  ['no', 'that'],
#  ['that', 'came', 'from', 'something', 'else'],
#  ['the', 'demogorgon'],
#  ['we', 're', 'in', 'deep', 'shit'],
#  ['will', 'your', 'action'],
#  ['don', 'know'],
#  ['fireball', 'him'],
#  ['have', 'to', 'roll', 'or', 'higher'],
# ...

# %%
story
# Out:
# [['something', 'is', 'coming'],
#  ['something', 'hungry', 'for', 'blood'],
#  ['shadow',
#   'grows',
#   'on',
#   'the',
#   'wall',
#   'behind',
#   'you',
#   'swallowing',
#   'you',
#   'in',
#   'darkness'],
#  ['it', 'is', 'almost', 'here'],
#  ['what', 'is', 'it'],
#  ['what', 'if', 'it', 'the', 'demogorgon'],
#  ['oh', 'jesus', 'we', 're', 'so', 'screwed', 'if', 'it', 'the', 'demogorgon'],
#  ['it', 'not', 'the', 'demogorgon'],
#  ['an', 'army', 'of', 'troglodytes', 'charge', 'into', 'the', 'chamber'],
#  ['troglodytes'],
#  ['told', 'ya'],
#  ['wait', 'minute'],
#  ['did', 'you', 'hear', 'that'],
#  ['that', 'that', 'sound'],
#  ['boom', 'boom'],
#  ['boom'],
#  ['that', 'didn', 'come', 'from', 'the', 'troglodytes'],
#  ['no', 'that'],
#  ['that', 'came', 'from', 'something', 'else'],
#  ['the', 'demogorgon'],
#  ['we', 're', 'in', 'deep', 'shit'],
#  ['will', 'your', 'action'],
#  ['don', 'know'],
#  ['fireball', 'him'],
#  ['have', 'to', 'roll', 'or', 'higher'],
# ...

# %%
model=gensim.models.Word2Vec(
    window=10,
    min_count=3,
    vector_size=100
)

# %%
model.build_vocab(story)

# %%
model.train(story,total_examples=model.corpus_count,epochs=model.epochs)
# Out:
# (462931, 684835)

# %%
model.wv.most_similar('henry')
# Out:
# [('because', 0.9979173541069031),
#  ('close', 0.9973176717758179),
#  ('monster', 0.9973102807998657),
#  ('always', 0.9972575902938843),
#  ('real', 0.9972202181816101),
#  ('any', 0.9972022771835327),
#  ('alive', 0.9971995949745178),
#  ('means', 0.9971882104873657),
#  ('normal', 0.997128427028656),
#  ('heard', 0.9971181750297546)]

# %%
model.wv.most_similar('el')
# Out:
# [('eleven', 0.9985427856445312),
#  ('play', 0.9983192086219788),
#  ('whatever', 0.9982002377510071),
#  ('both', 0.9981791973114014),
#  ('ready', 0.9981443285942078),
#  ('russians', 0.998041033744812),
#  ('coming', 0.9979694485664368),
#  ('mike', 0.9978995323181152),
#  ('lose', 0.9978814721107483),
#  ('girls', 0.9977121949195862)]

# %%
print(model.wv.vector_size)
print(len(model.wv.index_to_key))
# Out:
# 100
# 2900

# %%
print(model.wv.most_similar('mike', topn=10))
print(model.wv.most_similar('demogorgon', topn=10))
# Out:
# [('el', 0.9978994727134705), ('eleven', 0.9976242780685425), ('ready', 0.9976118206977844), ('yet', 0.9973759651184082), ('lose', 0.9973626136779785), ('whatever', 0.9973613619804382), ('owens', 0.997300922870636), ('girls', 0.9970476031303406), ('live', 0.9970179200172424), ('work', 0.9969950914382935)]
# [('girl', 0.997421383857727), ('bad', 0.997259259223938), ('family', 0.9972019791603088), ('worse', 0.9969286322593689), ('works', 0.9969027042388916), ('very', 0.9968980550765991), ('says', 0.9967180490493774), ('totally', 0.9966306090354919), ('hair', 0.996367871761322), ('only', 0.9961913228034973)]

# %%
model.wv.doesnt_match(['hopper','henry','vecna','russians'])
# Out:
# 'henry'

# %%
model.wv.get_normed_vectors()
# Out:
# array([[-0.07190482,  0.02668233,  0.01779894, ..., -0.09848639,
#          0.0567271 ,  0.01698673],
#        [-0.12475169,  0.16617487, -0.02180028, ..., -0.01782259,
#          0.06883576, -0.0219003 ],
#        [-0.10196055,  0.09765125, -0.08226629, ..., -0.12885267,
#          0.11003279,  0.02211263],
#        ...,
#        [-0.05754693,  0.06594137, -0.04398875, ..., -0.10286122,
#          0.0580158 , -0.05937828],
#        [-0.07678851,  0.13064909, -0.07521618, ..., -0.09165257,
#          0.11405759, -0.04748866],
#        [-0.04957498,  0.12442932, -0.08392482, ..., -0.07132117,
#          0.10062521, -0.07262801]], dtype=float32)

# %%
y=model.wv.index_to_key

# %%
y
# Out:
# ['you',
#  'the',
#  'it',
#  'to',
#  'that',
#  'and',
#  'what',
#  'we',
#  'is',
#  'this',
#  'no',
#  'me',
#  'just',
#  'he',
#  'of',
#  'in',
#  'know',
#  're',
#  'yeah',
#  'on',
#  'don',
#  'not',
#  'like',
#  'do',
#  'okay',
#  'was',
#  'are',
#  'right',
#  'your',
#  'but',
#  'my',
#  'go',
#  'so',
#  'she',
#  'can',
#  'all',
#  'for',
#  'here',
#  'there',
#  'they',
#  'be',
#  'have',
#  'oh',
#  'will',
#  'hey',
#  'with',
#  'get',
#  'if',
#  'come',
#  'out',
#  'him',
#  'about',
#  'think',
#  'up',
#  'her',
#  'shit',
#  'now',
#  'uh',
#  'gonna',
#  'let',
#  'at',
#  'how',
#  'us',
#  'where',
#  'see',
#  'one',
#  've',
#  'did',
#  'why',
#  'or',
#  'll',
#  'back',
#  'well',
#  'got',
#  'something',
#  'mean',
#  'need',
#  'want',
#  'then',
#  'who',
#  'good',
#  'going',
#  'time',
#  'from',
#  'sorry',
#  'yes',
#  'really',
#  'his',
#  'some',
#  'been',
#  'were',
#  'mike',
#  'way',
#  'look',
#  'tell',
#  'when',
# ...
